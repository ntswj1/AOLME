# %%
# !wget https://raw.githubusercontent.com/ivpcl/REVISION-3-Level-1-2019-English/main/Level1-Projects/AOLME.py
# Out:
# --2021-06-17 21:25:06--  https://raw.githubusercontent.com/ivpcl/REVISION-3-Level-1-2019-English/main/Level1-Projects/AOLME.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24462 (24K) [text/plain]
# Saving to: ‘AOLME.py.1’
#
# AOLME.py.1          100%[===================>]  23.89K  --.-KB/s    in 0s
#
# 2021-06-17 21:25:06 (111 MB/s) - ‘AOLME.py.1’ saved [24462/24462]

# %%
from AOLME import *

#Background
ncols = 20
nrows = 20
frame_1 = [["d6b46d"]*ncols for row in range(nrows)]
im_fill(frame_1, [1,1], [13,13], "20C923")
im_fill(frame_1, [2,2], [14,14], "20C923")
im_fill(frame_1, [3,3], [15,15], "20C923")
im_fill(frame_1, [2,2], [16,16], "20C923")
im_fill(frame_1, [1,1], [17,17], "20C923")
im_fill(frame_1, [4,4], [1,1], "20C923")
im_fill(frame_1, [5,5], [2,2], "20C923")
im_fill(frame_1, [6,6], [3,3], "20C923")
im_fill(frame_1, [5,5], [4,4], "20C923")
im_fill(frame_1, [4,4], [5,5], "20C923")
im_fill(frame_1, [6,7], [10,11], "20C923")
im_fill(frame_1, [7,7], [9,9], "20C923")
im_fill(frame_1, [7,7], [12,12], "20C923")
im_fill(frame_1, [10,11], [3,4], "20C923")
im_fill(frame_1, [11,11], [2,2], "20C923")
im_fill(frame_1, [11,11], [5,5], "20C923")
im_fill(frame_1, [11,11], [11,11], "20C923")
im_fill(frame_1, [12,12], [12,12], "20C923")
im_fill(frame_1, [13,13], [13,13], "20C923")
im_fill(frame_1, [12,12], [14,14], "20C923")
im_fill(frame_1, [11,11], [15,15], "20C923")
im_fill(frame_1, [15,15], [3,3], "20C923")
im_fill(frame_1, [16,16], [4,4], "20C923")
im_fill(frame_1, [17,17], [5,5], "20C923")
im_fill(frame_1, [16,16], [6,6], "20C923")
im_fill(frame_1, [15,15], [7,7], "20C923")
im_fill(frame_1, [17,17], [16,17], "20C923")
im_fill(frame_1, [18,18], [15,18], "20C923")
#im_show(frame_1)
#################################################SMALL SNAKE################################
#FRAME 2

small_snake = [["d6b46d"]*ncols for row in range(nrows)]

#Background
im_fill(small_snake, [1,1], [13,13], "20C923")
im_fill(small_snake, [2,2], [14,14], "20C923")
im_fill(small_snake, [3,3], [15,15], "20C923")
im_fill(small_snake, [2,2], [16,16], "20C923")
im_fill(small_snake, [1,1], [17,17], "20C923")
im_fill(small_snake, [4,4], [1,1], "20C923")
im_fill(small_snake, [5,5], [2,2], "20C923")
im_fill(small_snake, [6,6], [3,3], "20C923")
im_fill(small_snake, [5,5], [4,4], "20C923")
im_fill(small_snake, [4,4], [5,5], "20C923")
im_fill(small_snake, [6,7], [10,11], "20C923")
im_fill(small_snake, [7,7], [9,9], "20C923")
im_fill(small_snake, [7,7], [12,12], "20C923")
im_fill(small_snake, [10,11], [3,4], "20C923")
im_fill(small_snake, [11,11], [2,2], "20C923")
im_fill(small_snake, [11,11], [5,5], "20C923")
im_fill(small_snake, [11,11], [11,11], "20C923")
im_fill(small_snake, [12,12], [12,12], "20C923")
im_fill(small_snake, [13,13], [13,13], "20C923")
im_fill(small_snake, [12,12], [14,14], "20C923")
im_fill(small_snake, [11,11], [15,15], "20C923")
im_fill(small_snake, [15,15], [3,3], "20C923")
im_fill(small_snake, [16,16], [4,4], "20C923")
im_fill(small_snake, [17,17], [5,5], "20C923")
im_fill(small_snake,  [16,16], [6,6], "20C923")
im_fill(small_snake, [15,15], [7,7], "20C923")
im_fill(small_snake, [17,17], [16,17], "20C923")
im_fill(small_snake, [18,18], [15,18], "20C923")
#Small Snake
im_fill(small_snake, [0,0], [6,7], "E55F06")
im_fill(small_snake, [1,1], [7,8], "E55F06")
im_fill(small_snake, [2,2], [8,9], "E55F06")
im_fill(small_snake, [3,3], [9,10], "E55F06")
im_fill(small_snake, [4,4], [7,9], "E55F06")
im_fill(small_snake, [5,5], [7,8], "E55F06")
im_fill(small_snake, [6,6], [8,9], "E55F06")
im_fill(small_snake, [7,7], [9,10], "E55F06")
im_fill(small_snake, [8,8], [8,12], "E55F06")
im_fill(small_snake, [9,9], [8,12], "E55F06")
im_fill(small_snake, [10,10], [8,12], "E55F06")
im_fill(small_snake, [11,11], [9,11], "000000")
im_fill(small_snake, [12,12], [10,10], "E50A06")
im_fill(small_snake, [9,9], [9,9], "EF0758")
im_fill(small_snake, [9,9], [11,11], "EF0758")
#im_show(small_snake)

########################################MEDIUM SNAKE##############################################################
#Background
small_snake1 = [["d6b46d"]*ncols for row in range(nrows)]


im_fill(small_snake1, [1,1], [13,13], "20C923")
im_fill(small_snake1, [2,2], [14,14], "20C923")
im_fill(small_snake1, [3,3], [15,15], "20C923")
im_fill(small_snake1, [2,2], [16,16], "20C923")
im_fill(small_snake1, [1,1], [17,17], "20C923")
im_fill(small_snake1, [4,4], [1,1], "20C923")
im_fill(small_snake1, [5,5], [2,2], "20C923")
im_fill(small_snake1, [6,6], [3,3], "20C923")
im_fill(small_snake1, [5,5], [4,4], "20C923")
im_fill(small_snake1, [4,4], [5,5], "20C923")
im_fill(small_snake1, [6,7], [10,11], "20C923")
im_fill(small_snake1, [7,7], [9,9], "20C923")
im_fill(small_snake1, [7,7], [12,12], "20C923")
im_fill(small_snake1, [10,11], [3,4], "20C923")
im_fill(small_snake1, [11,11], [2,2], "20C923")
im_fill(small_snake1, [11,11], [5,5], "20C923")
im_fill(small_snake1, [11,11], [11,11], "20C923")
im_fill(small_snake1, [12,12], [12,12], "20C923")
im_fill(small_snake1, [13,13], [13,13], "20C923")
im_fill(small_snake1, [12,12], [14,14], "20C923")
im_fill(small_snake1, [11,11], [15,15], "20C923")
im_fill(small_snake1, [15,15], [3,3], "20C923")
im_fill(small_snake1, [16,16], [4,4], "20C923")
im_fill(small_snake1, [17,17], [5,5], "20C923")
im_fill(small_snake1,  [16,16], [6,6], "20C923")
im_fill(small_snake1, [15,15], [7,7], "20C923")
im_fill(small_snake1, [17,17], [16,17], "20C923")
im_fill(small_snake1, [18,18], [15,18], "20C923")
#Medium Snake
im_fill(small_snake1, [0,0], [6,7], "E55F06")
im_fill(small_snake1, [1,1], [7,8], "E55F06")
im_fill(small_snake1, [2,2], [8,9], "E55F06")
im_fill(small_snake1, [3,3], [9,10], "E55F06")
im_fill(small_snake1, [4,4], [8,10], "E55F06")
im_fill(small_snake1, [5,5], [8,9], "E55F06")
im_fill(small_snake1, [6,6], [7,8], "E55F06")
im_fill(small_snake1, [7,7], [6,7], "E55F06")
im_fill(small_snake1, [8,8], [5,6], "E55F06")
im_fill(small_snake1, [9,9], [6,8], "E55F06")
im_fill(small_snake1, [10,10], [8,9], "E55F06")
im_fill(small_snake1, [11,11], [9,13], "E55F06")
im_fill(small_snake1, [12,12], [9,13], "E55F06")
im_fill(small_snake1, [13,13], [9,13], "E55F06")
im_fill(small_snake1, [14,14], [10,12], "000000")
im_fill(small_snake1, [15,15], [11,11], "E50A06")
im_fill(small_snake1, [12,12], [10,10], "EF0758")
im_fill(small_snake1, [12,12], [12,12], "EF0758")
#im_show(small_snake1)
#
##################################LARGE SNAKE################################################

small_snake2 = [["d6b46d"]*ncols for row in range(nrows)]

#Background
im_fill(small_snake2, [1,1], [13,13], "20C923")
im_fill(small_snake2, [2,2], [14,14], "20C923")
im_fill(small_snake2, [3,3], [15,15], "20C923")
im_fill(small_snake2, [2,2], [16,16], "20C923")
im_fill(small_snake2, [1,1], [17,17], "20C923")
im_fill(small_snake2, [4,4], [1,1], "20C923")
im_fill(small_snake2, [5,5], [2,2], "20C923")
im_fill(small_snake2, [6,6], [3,3], "20C923")
im_fill(small_snake2, [5,5], [4,4], "20C923")
im_fill(small_snake2, [4,4], [5,5], "20C923")
im_fill(small_snake2, [6,7], [10,11], "20C923")
im_fill(small_snake2, [7,7], [9,9], "20C923")
im_fill(small_snake2, [7,7], [12,12], "20C923")
im_fill(small_snake2, [10,11], [3,4], "20C923")
im_fill(small_snake2, [11,11], [2,2], "20C923")
im_fill(small_snake2, [11,11], [5,5], "20C923")
im_fill(small_snake2, [11,11], [11,11], "20C923")
im_fill(small_snake2, [12,12], [12,12], "20C923")
im_fill(small_snake2, [13,13], [13,13], "20C923")
im_fill(small_snake2, [12,12], [14,14], "20C923")
im_fill(small_snake2, [11,11], [15,15], "20C923")
im_fill(small_snake2, [15,15], [3,3], "20C923")
im_fill(small_snake2, [16,16], [4,4], "20C923")
im_fill(small_snake2, [17,17], [5,5], "20C923")
im_fill(small_snake2,  [16,16], [6,6], "20C923")
im_fill(small_snake2, [15,15], [7,7], "20C923")
im_fill(small_snake2, [17,17], [16,17], "20C923")
im_fill(small_snake2, [18,18], [15,18], "20C923")
#Large Snake
im_fill(small_snake2, [0,0], [6,7], "E55F06")
im_fill(small_snake2, [1,1], [7,8], "E55F06")
im_fill(small_snake2, [2,2], [8,9], "E55F06")
im_fill(small_snake2, [3,3], [9,10], "E55F06")
im_fill(small_snake2, [4,4], [8,10], "E55F06")
im_fill(small_snake2, [5,5], [8,9], "E55F06")
im_fill(small_snake2, [6,6], [7,8], "E55F06")
im_fill(small_snake2, [7,7], [6,7], "E55F06")
im_fill(small_snake2, [8,8], [5,6], "E55F06")
im_fill(small_snake2, [9,9], [6,8], "E55F06")
im_fill(small_snake2, [10,10], [8,9], "E55F06")
im_fill(small_snake2, [11,11], [9,10], "E55F06")
im_fill(small_snake2, [12,12], [8,10], "E55F06")
im_fill(small_snake2, [13,13], [8,8], "E55F06")
im_fill(small_snake2, [14,14], [7,8], "E55F06")
im_fill(small_snake2, [15,15], [6,10], "E55F06")
im_fill(small_snake2, [16,16], [6,10], "E55F06")
im_fill(small_snake2, [17,17], [6,10], "E55F06")
#MOUTH
im_fill(small_snake2, [18,18], [7,9], "000000")
#lengua
im_fill(small_snake2, [19,19], [8,8], "E50A06")

#eyes
im_fill(small_snake2, [16,16], [7,7], "EF0758")
im_fill(small_snake2, [16,16], [9,9], "EF0758")
#im_show(small_snake2)




#####################################################################################################
scarywoman = [["000000"]*ncols for row in range(nrows)]

#hair
im_fill(scarywoman,[2,2],[3,15],"CEA758")
im_fill(scarywoman,[3,3],[2,15],"CEA758")
im_fill(scarywoman,[4,4],[2,16],"CEA758")
im_fill(scarywoman,[5,5],[2,3],"CEA758")
im_fill(scarywoman,[5,5],[5,5],"CEA758")
im_fill(scarywoman,[5,5],[7,7],"CEA758")
im_fill(scarywoman,[5,5],[9,9],"CEA758")
im_fill(scarywoman,[5,5],[11,11],"CEA758")
im_fill(scarywoman,[5,5],[15,16],"CEA758")
im_fill(scarywoman,[6,6],[2,4],"CEA758")
im_fill(scarywoman,[6,6],[16,16],"CEA758")
im_fill(scarywoman,[7,7],[2,3],"CEA758")
im_fill(scarywoman,[7,7],[16,16],"CEA758")
im_fill(scarywoman,[8,8],[2,3],"CEA758")
im_fill(scarywoman,[8,8],[16,16],"CEA758")
im_fill(scarywoman,[9,9],[2,3],"CEA758")
im_fill(scarywoman,[9,9],[16,17],"CEA758")
im_fill(scarywoman,[10,10],[1,3],"CEA758")
im_fill(scarywoman,[10,10],[16,18],"CEA758")
im_fill(scarywoman,[11,11],[1,3],"CEA758")
im_fill(scarywoman,[11,11],[16,18],"CEA758")
im_fill(scarywoman,[12,12],[1,3],"CEA758")
im_fill(scarywoman,[12,12],[16,18],"CEA758")
im_fill(scarywoman,[13,13],[1,3],"CEA758")
im_fill(scarywoman,[13,13],[16,18],"CEA758")
im_fill(scarywoman,[14,14],[1,3],"CEA758")
im_fill(scarywoman,[14,14],[16,18],"CEA758")
im_fill(scarywoman,[15,15],[1,4],"CEA758")
im_fill(scarywoman,[15,15],[15,18],"CEA758")
im_fill(scarywoman,[16,16],[1,4],"CEA758")
im_fill(scarywoman,[16,16],[15,18],"CEA758")
im_fill(scarywoman,[17,17],[1,5],"CEA758")
im_fill(scarywoman,[17,17],[14,18],"CEA758")

#eyes
im_fill(scarywoman,[7,7],[12,12],"54724C")
im_fill(scarywoman,[7,7],[7,7],"54724C")
im_fill(scarywoman,[8,8],[6,8],"54724C")
im_fill(scarywoman,[8,8],[11,13],"54724C")
im_fill(scarywoman,[9,9],[7,7],"54724C")
im_fill(scarywoman,[9,9],[12,12],"54724C")
im_fill(scarywoman,[8,8],[7,7],"000000")
im_fill(scarywoman,[8,8],[12,12],"000000")

#skin
im_fill(scarywoman,[4,4],[4,4],"D3EDCF")
im_fill(scarywoman,[4,4],[6,6],"D3EDCF")
im_fill(scarywoman,[4,4],[8,9],"D3EDCF")
im_fill(scarywoman,[4,4],[11,12],"D3EDCF")
im_fill(scarywoman,[5,5],[6,6],"D3EDCF")
im_fill(scarywoman,[5,5],[8,8],"D3EDCF")
im_fill(scarywoman,[5,5],[10,10],"D3EDCF")
im_fill(scarywoman,[5,5],[12,14],"D3EDCF")
im_fill(scarywoman,[6,6],[6,15],"D3EDCF")
im_fill(scarywoman,[7,7],[4,6],"D3EDCF")
im_fill(scarywoman,[7,7],[8,11],"D3EDCF")
im_fill(scarywoman,[7,7],[13,15],"D3EDCF")
im_fill(scarywoman,[8,8],[4,5],"D3EDCF")
im_fill(scarywoman,[8,8],[9,10],"D3EDCF")
im_fill(scarywoman,[8,8],[14,15],"D3EDCF")
im_fill(scarywoman,[9,9],[4,6],"D3EDCF")
im_fill(scarywoman,[9,9],[8,11],"D3EDCF")
im_fill(scarywoman,[9,9],[13,15],"D3EDCF")
im_fill(scarywoman,[10,10],[4,4],"D3EDCF")
im_fill(scarywoman,[10,10],[6,8],"D3EDCF")
im_fill(scarywoman,[10,10],[10,14],"D3EDCF")
im_fill(scarywoman,[11,11],[4,4],"D3EDCF")
im_fill(scarywoman,[11,11],[6,9],"D3EDCF")
im_fill(scarywoman,[11,11],[11,13],"D3EDCF")
im_fill(scarywoman,[11,11],[15,15],"D3EDCF")
im_fill(scarywoman,[12,12],[4,4],"D3EDCF")
im_fill(scarywoman,[12,12],[6,15],"D3EDCF")
im_fill(scarywoman,[13,13],[4,5],"D3EDCF")
im_fill(scarywoman,[13,13],[14,15],"D3EDCF")
im_fill(scarywoman,[14,14],[4,6],"D3EDCF")
im_fill(scarywoman,[14,14],[13,15],"D3EDCF")
im_fill(scarywoman,[15,15],[6,6],"D3EDCF")
im_fill(scarywoman,[15,15],[12,14],"D3EDCF")
im_fill(scarywoman,[16,16],[7,14],"D3EDCF")
im_fill(scarywoman,[17,17],[8,13],"D3EDCF")

#BLOOD
im_fill(scarywoman,[5,5],[4,4],"E50A06")
im_fill(scarywoman,[6,6],[5,5],"E50A06")
im_fill(scarywoman,[10,10],[5,5],"E50A06")
im_fill(scarywoman,[10,10],[9,9],"E50A06")
im_fill(scarywoman,[10,10],[15,15],"E50A06")
im_fill(scarywoman,[11,11],[5,5],"E50A06")
im_fill(scarywoman,[11,11],[10,10],"E50A06")
im_fill(scarywoman,[11,11],[14,14],"E50A06")
im_fill(scarywoman,[12,12],[5,5],"E50A06")
im_fill(scarywoman,[15,15],[5,5],"E50A06")
im_fill(scarywoman,[15,15],[7,7],"E50A06")
im_fill(scarywoman,[16,16],[5,6],"E50A06")
im_fill(scarywoman,[17,17],[6,7],"E50A06")

#lips
im_fill(scarywoman,[13,13],[6,13],"330909")
im_fill(scarywoman,[14,14],[7,7],"330909")
im_fill(scarywoman,[14,14],[12,12],"330909")
im_fill(scarywoman,[15,15],[8,11],"330909")

#TEETH
im_fill(scarywoman,[14,14],[8,11],"000000")




#im_show(scarywoman)

frame_list = [frame_1,small_snake,small_snake1,small_snake2,scarywoman]
fps = 1
play_video = vid_show(frame_list,fps)

# %%
from IPython.display import HTML
HTML(play_video.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
